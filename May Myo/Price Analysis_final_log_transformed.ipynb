# %% [markdown]
# # Refer to SF EDA notebook for Price EDA (Section 5 & 10)

# %% [markdown]
# # Import Libraries

# %%
# pip install -r "../requirements.txt"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %% [markdown]
# # Import Data

# %%
SF_df = pd.read_pickle("remove_features_without_encoding.pkl")
SF_df.tail(5)
# Out:
#      host_response_time  host_response_rate  host_acceptance_rate  \
# 5288     within an hour                 1.0                  0.99
# 5289     within an hour                 1.0                  1.00
# 5290                  -                 0.0                  1.00
# 5291                  -                 0.0                  1.00
# 5292     within an hour                 1.0                  1.00
#
#       host_is_superhost  host_listings_count neighbourhood_cleansed  \
# 5288                  1                    1      Visitacion Valley
# 5289                  1                    1      Visitacion Valley
# 5290                  0                    3      Visitacion Valley
# 5291                  0                    0      Visitacion Valley
# 5292                  0                    0      Visitacion Valley
#
#                   property_type        room_type  accommodates  bathrooms  \
# 5288           Entire townhouse  Entire home/apt             5        1.0
# 5289          Entire guesthouse  Entire home/apt             2        1.0
# 5290          Entire guesthouse  Entire home/apt             2        1.0
# 5291         Entire guest suite  Entire home/apt             2        1.0
# 5292  Private room in apartment     Private room             4        1.0
#
#       ... game console  stair gates  fireplace guards  pool  pocket wifi  \
# 5288  ...            0            0                 0     0            0
# 5289  ...            0            0                 0     0            0
# 5290  ...            0            0                 0     0            0
# 5291  ...            0            0                 0     0            0
# 5292  ...            0            0                 0     0            0
#
#       changing table  beach essentials  window guards  ev charger  beachfront
# 5288               0                 0              0           0           0
# 5289               0                 0              0           0           0
# 5290               0                 0              0           0           0
# 5291               0                 0              1           0           0
# 5292               0                 0              0           0           0
#
# [5 rows x 80 columns]

# %%
SF_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5293 entries, 0 to 5292
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   host_response_time          5293 non-null   object
#  1   host_response_rate          5293 non-null   float64
#  2   host_acceptance_rate        5293 non-null   float64
#  3   host_is_superhost           5293 non-null   int32
#  4   host_listings_count         5293 non-null   int64
#  5   neighbourhood_cleansed      5293 non-null   object
#  6   property_type               5293 non-null   object
#  7   room_type                   5293 non-null   object
#  8   accommodates                5293 non-null   int64
#  9   bathrooms                   5293 non-null   float64
#  10  amenities                   5293 non-null   object
#  11  price                       5293 non-null   float64
#  12  minimum_nights              5293 non-null   int64
#  13  review_scores_rating        5293 non-null   float64
#  14  reviews_per_month           5293 non-null   float64
#  15  price_log                   5293 non-null   float64
#  16  sentiment_compound          5293 non-null   float64
#  17  SafeIndex_Score             5293 non-null   float64
#  18  wifi                        5293 non-null   int64
#  19  heating                     5293 non-null   int64
#  20  smoke alarm                 5293 non-null   int64
#  21  essentials                  5293 non-null   int64
#  22  hair dryer                  5293 non-null   int64
#  23  tv                          5293 non-null   int64
#  24  kitchen                     5293 non-null   int64
#  25  hot water                   5293 non-null   int64
#  26  fire extinguisher           5293 non-null   int64
#  27  washer                      5293 non-null   int64
#  28  coffee maker                5293 non-null   int64
#  29  refrigerator                5293 non-null   int64
#  30  free street parking         5293 non-null   int64
#  31  first aid kit               5293 non-null   int64
#  32  bed linens                  5293 non-null   int64
#  33  oven                        5293 non-null   int64
#  34  private entrance            5293 non-null   int64
#  35  dishwasher                  5293 non-null   int64
#  36  cable tv                    5293 non-null   int64
#  37  luggage dropoff allowed     5293 non-null   int64
#  38  long term stays allowed     5293 non-null   int64
#  39  garden or backyard          5293 non-null   int64
#  40  patio or balcony            5293 non-null   int64
#  41  lock on bedroom door        5293 non-null   int64
#  42  lockbox                     5293 non-null   int64
#  43  keypad                      5293 non-null   int64
#  44  free parking on premises    5293 non-null   int64
#  45  elevator                    5293 non-null   int64
#  46  bathtub                     5293 non-null   int64
#  47  indoor fireplace            5293 non-null   int64
#  48  paid parking off premises   5293 non-null   int64
#  49  air conditioning            5293 non-null   int64
#  50  pack 'n play/travel crib    5293 non-null   int64
#  51  bbq grill                   5293 non-null   int64
#  52  breakfast                   5293 non-null   int64
#  53  host greets you             5293 non-null   int64
#  54  room-darkening shades       5293 non-null   int64
#  55  children's books and toys   5293 non-null   int64
#  56  shower gel                  5293 non-null   int64
#  57  single level home           5293 non-null   int64
#  58  paid parking on premises    5293 non-null   int64
#  59  building staff              5293 non-null   int64
#  60  ethernet connection         5293 non-null   int64
#  61  smart lock                  5293 non-null   int64
#  62  hot tub                     5293 non-null   int64
#  63  private living room         5293 non-null   int64
#  64  high chair                  5293 non-null   int64
#  65  baking sheet                5293 non-null   int64
#  66  bathroom essentials         5293 non-null   int64
#  67  cleaning before checkout    5293 non-null   int64
#  68  crib                        5293 non-null   int64
#  69  babysitter recommendations  5293 non-null   int64
#  70  game console                5293 non-null   int64
#  71  stair gates                 5293 non-null   int64
#  72  fireplace guards            5293 non-null   int64
#  73  pool                        5293 non-null   int64
#  74  pocket wifi                 5293 non-null   int64
#  75  changing table              5293 non-null   int64
#  76  beach essentials            5293 non-null   int64
#  77  window guards               5293 non-null   int64
#  78  ev charger                  5293 non-null   int64
#  79  beachfront                  5293 non-null   int64
# dtypes: float64(9), int32(1), int64(65), object(5)
# memory usage: 3.2+ MB

# %% [markdown]
# # Different column type name lists

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_columns = SF_df.select_dtypes(include=numerics).columns.to_list()
bool_columns = SF_df.select_dtypes(include='bool').columns.to_list()
object_columns = SF_df.select_dtypes(include='object').columns.to_list()
print(f"No. of numeric cols: {len(numeric_columns)}")
print(f"No. of boolean cols: {len(bool_columns)}")
print(f"No. of object cols: {len(object_columns)}")
print(f"Total: {len(numeric_columns)+len(bool_columns)+len(object_columns)}")
print("Object Columns :",object_columns)
# Out:
# No. of numeric cols: 75
# No. of boolean cols: 0
# No. of object cols: 5
# Total: 80
# Object Columns : ['host_response_time', 'neighbourhood_cleansed', 'property_type', 'room_type', 'amenities']

# %%
SF_df.isnull().sum()
# Out:
# host_response_time      0
# host_response_rate      0
# host_acceptance_rate    0
# host_is_superhost       0
# host_listings_count     0
#                        ..
# changing table          0
# beach essentials        0
# window guards           0
# ev charger              0
# beachfront              0
# Length: 80, dtype: int64

# %% [markdown]
# ## Transforming categorical columns to numeric columns and combine all into new df

# %%
new_SF_df = SF_df[numeric_columns]
new_SF_df.shape
# Out:
# (5293, 75)

# %%
for categorical_col in object_columns[:-1]:
    new_SF_df = pd.concat([new_SF_df, pd.get_dummies(SF_df[categorical_col])], axis=1)

# %%
new_SF_df
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                   1.00                  0.99                  1
# 1                   0.97                  0.79                  1
# 2                   0.50                  0.76                  1
# 3                   0.50                  0.76                  1
# 4                   1.00                  1.00                  0
# ...                  ...                   ...                ...
# 5288                1.00                  0.99                  1
# 5289                1.00                  1.00                  1
# 5290                0.00                  1.00                  0
# 5291                0.00                  1.00                  0
# 5292                1.00                  1.00                  0
#
#       host_listings_count  accommodates  bathrooms  price  minimum_nights  \
# 0                       1             3        1.0  132.0               2
# 1                      38             5        2.0  166.0              30
# 2                       3             2        1.0  130.0               2
# 3                       3             2        1.0  110.0               2
# 4                       2            10        2.0  480.0               3
# ...                   ...           ...        ...    ...             ...
# 5288                    1             5        1.0  121.0               2
# 5289                    1             2        1.0  151.0               2
# 5290                    3             2        1.0  179.0               2
# 5291                    0             2        1.0  190.0              30
# 5292                    0             4        1.0   85.0               1
#
#       review_scores_rating  reviews_per_month  ...  Shared room in hostel  \
# 0                     97.0               1.91  ...                      0
# 1                     91.0               0.15  ...                      0
# 2                     97.0               3.92  ...                      0
# 3                     98.0               3.73  ...                      0
# 4                     91.0               0.32  ...                      0
# ...                    ...                ...  ...                    ...
# 5288                 100.0               0.13  ...                      0
# 5289                  99.0               4.11  ...                      0
# 5290                 100.0               0.47  ...                      0
# 5291                 100.0               0.48  ...                      0
# 5292                 100.0               0.34  ...                      0
#
#       Shared room in house  Shared room in loft  Shared room in townhouse  \
# 0                        0                    0                         0
# 1                        0                    0                         0
# 2                        0                    0                         0
# 3                        0                    0                         0
# 4                        0                    0                         0
# ...                    ...                  ...                       ...
# 5288                     0                    0                         0
# 5289                     0                    0                         0
# 5290                     0                    0                         0
# 5291                     0                    0                         0
# 5292                     0                    0                         0
#
#       Shared room in villa  Tiny house  Entire home/apt  Hotel room  \
# 0                        0           0                1           0
# 1                        0           0                1           0
# 2                        0           0                0           0
# 3                        0           0                0           0
# 4                        0           0                1           0
# ...                    ...         ...              ...         ...
# 5288                     0           0                1           0
# 5289                     0           0                1           0
# 5290                     0           0                1           0
# 5291                     0           0                1           0
# 5292                     0           0                0           0
#
#       Private room  Shared room
# 0                0            0
# 1                0            0
# 2                1            0
# 3                1            0
# 4                0            0
# ...            ...          ...
# 5288             0            0
# 5289             0            0
# 5290             0            0
# 5291             0            0
# 5292             1            0
#
# [5293 rows x 168 columns]

# %%
new_SF_df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False])

# %%
new_SF_df.columns.values[166] = "Private room (Room Type)"
new_SF_df.columns.values[166]
# Out:
# 'Private room (Room Type)'

# %%
new_SF_df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
print(new_SF_df.duplicated().any())
if new_SF_df.duplicated().any():
    duplicate_rows = new_SF_df[new_SF_df.duplicated()]
    print(duplicate_rows)
    new_SF_df = new_SF_df.drop_duplicates()
    print("Duplicates Removed")
print(new_SF_df.duplicated().any())
# Out:
# False
# False

# %%
new_SF_df
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                   1.00                  0.99                  1
# 1                   0.97                  0.79                  1
# 2                   0.50                  0.76                  1
# 3                   0.50                  0.76                  1
# 4                   1.00                  1.00                  0
# ...                  ...                   ...                ...
# 5288                1.00                  0.99                  1
# 5289                1.00                  1.00                  1
# 5290                0.00                  1.00                  0
# 5291                0.00                  1.00                  0
# 5292                1.00                  1.00                  0
#
#       host_listings_count  accommodates  bathrooms  price  minimum_nights  \
# 0                       1             3        1.0  132.0               2
# 1                      38             5        2.0  166.0              30
# 2                       3             2        1.0  130.0               2
# 3                       3             2        1.0  110.0               2
# 4                       2            10        2.0  480.0               3
# ...                   ...           ...        ...    ...             ...
# 5288                    1             5        1.0  121.0               2
# 5289                    1             2        1.0  151.0               2
# 5290                    3             2        1.0  179.0               2
# 5291                    0             2        1.0  190.0              30
# 5292                    0             4        1.0   85.0               1
#
#       review_scores_rating  reviews_per_month  ...  Shared room in hostel  \
# 0                     97.0               1.91  ...                      0
# 1                     91.0               0.15  ...                      0
# 2                     97.0               3.92  ...                      0
# 3                     98.0               3.73  ...                      0
# 4                     91.0               0.32  ...                      0
# ...                    ...                ...  ...                    ...
# 5288                 100.0               0.13  ...                      0
# 5289                  99.0               4.11  ...                      0
# 5290                 100.0               0.47  ...                      0
# 5291                 100.0               0.48  ...                      0
# 5292                 100.0               0.34  ...                      0
#
#       Shared room in house  Shared room in loft  Shared room in townhouse  \
# 0                        0                    0                         0
# 1                        0                    0                         0
# 2                        0                    0                         0
# 3                        0                    0                         0
# 4                        0                    0                         0
# ...                    ...                  ...                       ...
# 5288                     0                    0                         0
# 5289                     0                    0                         0
# 5290                     0                    0                         0
# 5291                     0                    0                         0
# 5292                     0                    0                         0
#
#       Shared room in villa  Tiny house  Entire home/apt  Hotel room  \
# 0                        0           0                1           0
# 1                        0           0                1           0
# 2                        0           0                0           0
# 3                        0           0                0           0
# 4                        0           0                1           0
# ...                    ...         ...              ...         ...
# 5288                     0           0                1           0
# 5289                     0           0                1           0
# 5290                     0           0                1           0
# 5291                     0           0                1           0
# 5292                     0           0                0           0
#
#       Private room (Room Type)  Shared room
# 0                            0            0
# 1                            0            0
# 2                            1            0
# 3                            1            0
# 4                            0            0
# ...                        ...          ...
# 5288                         0            0
# 5289                         0            0
# 5290                         0            0
# 5291                         0            0
# 5292                         1            0
#
# [5293 rows x 168 columns]

# %% [markdown]
# # Train/Test split

# %%
from sklearn.model_selection import train_test_split
y = new_SF_df['price_log'] # target/dependent variable
x = new_SF_df.drop(['price','price_log'], axis =1) # independent variables

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Train/Test w Random Forest Algorithm

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=500, 
                               criterion='mse', 
                               random_state=3, 
                               n_jobs=-1)
rf.fit(X_train, y_train)
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 0.331
# R^2 test: 0.718

# %% [markdown]
# ## Feature Importance of Random Forest Algorithm

# %%
coefs_df = pd.DataFrame()
coefs_df['feature'] = X_train.columns
coefs_df['coefs'] = rf.feature_importances_
coefs_df.sort_values('coefs', ascending=False).head(20)
# Out:
#                       feature     coefs
# 4                accommodates  0.292494
# 6              minimum_nights  0.081778
# 162           Entire home/apt  0.064608
# 8           reviews_per_month  0.057034
# 165               Shared room  0.055106
# 5                   bathrooms  0.039243
# 9          sentiment_compound  0.038801
# 3         host_listings_count  0.030773
# 7        review_scores_rating  0.025427
# 10            SafeIndex_Score  0.025223
# 1        host_acceptance_rate  0.021373
# 42           air conditioning  0.017900
# 164  Private room (Room Type)  0.015369
# 0          host_response_rate  0.015208
# 28                 dishwasher  0.012348
# 139     Private room in house  0.008016
# 16                         tv  0.006877
# 29                   cable tv  0.005314
# 40           indoor fireplace  0.004269
# 20                     washer  0.004234

# %%
feat_imp = pd.Series(rf.feature_importances_, index=X_train.columns)
feat_imp.nlargest(20).plot(kind='barh', figsize=(10,6))

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## Train/Test w LightGBM

# %%
from lightgbm import LGBMRegressor

fit_params={
    "early_stopping_rounds":20, 
            "eval_metric" : 'rmse', 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            'verbose': 100,
            'feature_name': 'auto', 
            'categorical_feature': 'auto'
           }
        
class LGBMRegressor_GainFE(LGBMRegressor):
    @property
    def feature_importances_(self):
        if self._n_features is None:
            raise LGBMNotFittedError('No feature_importances found. Need to call fit beforehand.')
        return self.booster_.feature_importance(importance_type='gain')
        
clf = LGBMRegressor_GainFE(num_leaves= 25, max_depth=20, 
                         random_state=0, 
                         silent=True, 
                         metric='rmse', 
                         n_jobs=4, 
                         n_estimators=1000,
                         colsample_bytree=0.9,
                         subsample=0.9,
                         learning_rate=0.01)
clf.fit(X_train.values, y_train.values, **fit_params)
y_pred = clf.predict(X_test.values)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# Training until validation scores don't improve for 20 rounds
# [100]	valid's rmse: 0.415753
# [200]	valid's rmse: 0.357642
# [300]	valid's rmse: 0.338459
# [400]	valid's rmse: 0.329538
# [500]	valid's rmse: 0.326548
# [600]	valid's rmse: 0.324694
# Early stopping, best iteration is:
# [654]	valid's rmse: 0.324267
# R^2 test: 0.730

# %% [markdown]
# ## Feature Importance of LightGBM

# %%
feat_imp = pd.Series(clf.feature_importances_, index=x.columns)
feat_imp.nlargest(20).plot(kind='barh', figsize=(10,6))

# %%
coefs_df = pd.DataFrame()
coefs_df['feature'] = x.columns
coefs_df['coefs'] = clf.feature_importances_
coefs_df.sort_values('coefs', ascending=False).head(20)
# Out:
#                       feature         coefs
# 4                accommodates  23221.199503
# 162           Entire home/apt   5923.298608
# 6              minimum_nights   5641.856240
# 165               Shared room   3567.422366
# 5                   bathrooms   3544.962777
# 8           reviews_per_month   2768.182576
# 3         host_listings_count   2106.879804
# 7        review_scores_rating   1857.176951
# 10            SafeIndex_Score   1593.682967
# 1        host_acceptance_rate   1451.384653
# 164  Private room (Room Type)   1406.653357
# 42           air conditioning   1265.414705
# 0          host_response_rate   1177.931278
# 9          sentiment_compound   1105.850284
# 28                 dishwasher    972.439125
# 139     Private room in house    835.312071
# 16                         tv    725.025831
# 29                   cable tv    483.000825
# 11                       wifi    404.368664
# 59        bathroom essentials    399.209371

# %% [markdown]
# # Gradient Boosting

# %% [markdown]
# ## Train/Test w Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor


gboost = GradientBoostingRegressor(n_estimators=500, 
                               criterion='mse', 
                               random_state=3)
gboost.fit(X_train, y_train)
y_train_pred = gboost.predict(X_train)
y_test_pred = gboost.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 0.336
# R^2 test: 0.710

# %% [markdown]
# ## Feature Importance of Gradient Boosting

# %%
coefs_df = pd.DataFrame()
coefs_df['feature'] = X_train.columns
coefs_df['coefs'] = gboost.feature_importances_
coefs_df.sort_values('coefs', ascending=False).head(20)
# Out:
#                       feature     coefs
# 4                accommodates  0.298081
# 6              minimum_nights  0.093518
# 162           Entire home/apt  0.086703
# 165               Shared room  0.064816
# 5                   bathrooms  0.054590
# 8           reviews_per_month  0.036109
# 7        review_scores_rating  0.031893
# 164  Private room (Room Type)  0.026178
# 0          host_response_rate  0.024095
# 3         host_listings_count  0.023848
# 9          sentiment_compound  0.021835
# 10            SafeIndex_Score  0.021445
# 1        host_acceptance_rate  0.017557
# 42           air conditioning  0.015755
# 16                         tv  0.015190
# 28                 dishwasher  0.011071
# 11                       wifi  0.007908
# 29                   cable tv  0.007218
# 40           indoor fireplace  0.006056
# 139     Private room in house  0.005844

# %%
feat_imp = pd.Series(gboost.feature_importances_, index=X_train.columns)
feat_imp.nlargest(20).plot(kind='barh', figsize=(10,6))

# %% [markdown]
# # XGBoost and its Feature Importance

# %%
import xgboost as xgb

# Fitting the model
xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train, y_train)
training_preds_xgb_reg = xgb_reg.predict(X_train)
val_preds_xgb_reg = xgb_reg.predict(X_test)

# Printing the results

print("\nTraining MSE:", round(mean_squared_error(y_train, training_preds_xgb_reg),4))
print("Validation MSE:", round(mean_squared_error(y_test, val_preds_xgb_reg),4))
print("Validation RMSE:", round(mean_squared_error(y_test, val_preds_xgb_reg)**0.5,4))
print("\nTraining r2:", round(r2_score(y_train, training_preds_xgb_reg),4))
print("Validation r2:", round(r2_score(y_test, val_preds_xgb_reg),4))

# Producing a dataframe of feature importances
ft_weights_xgb_reg = pd.DataFrame(xgb_reg.feature_importances_, columns=['weight'], index=X_train.columns)
ft_weights_xgb_reg.sort_values('weight', inplace=True)

# Plotting feature importances
plt.figure(figsize=(8,20))
plt.barh(ft_weights_xgb_reg.index, ft_weights_xgb_reg.weight, align='center') 
plt.title("Feature importances in the XGBoost model", fontsize=14)
plt.xlabel("Feature importance")
plt.margins(y=0.01)
plt.show()
# Out:
# Training MSE: 0.0189
# Validation MSE: 0.1153
# Validation RMSE: 0.3395
#
# Training r2: 0.954
# Validation r2: 0.7037

# %% [markdown]
# # Neural Network Model

# %%
from keras import models, layers, optimizers, regularizers
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG

# Building the model
nn2 = models.Sequential()
nn2.add(layers.Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(512, activation='relu'))
nn2.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn2.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Printing the model summary
print(nn2.summary())

# Training the model
nn2_history = nn2.fit(X_train,
                  y_train,
                  epochs=100,
                  batch_size=256,
                  validation_split = 0.1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               21376
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 252,289
# Trainable params: 252,289
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 14/14 [==============================] - 0s 27ms/step - loss: 30.4141 - mean_squared_error: 30.4141 - val_loss: 2.7164 - val_mean_squared_error: 2.7164
# Epoch 2/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2.1810 - mean_squared_error: 2.1810 - val_loss: 0.9936 - val_mean_squared_error: 0.9936
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.8254 - mean_squared_error: 0.8254 - val_loss: 0.6065 - val_mean_squared_error: 0.6065
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5789 - mean_squared_error: 0.5789 - val_loss: 0.5114 - val_mean_squared_error: 0.5114
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.4529 - mean_squared_error: 0.4529 - val_loss: 0.3966 - val_mean_squared_error: 0.3966
# Epoch 6/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3764 - mean_squared_error: 0.3764 - val_loss: 0.3365 - val_mean_squared_error: 0.3365
# Epoch 7/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3226 - mean_squared_error: 0.3226 - val_loss: 0.2964 - val_mean_squared_error: 0.2964
# Epoch 8/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3274 - mean_squared_error: 0.3274 - val_loss: 0.2657 - val_mean_squared_error: 0.2657
# Epoch 9/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2596 - mean_squared_error: 0.2596 - val_loss: 0.2604 - val_mean_squared_error: 0.2604
# Epoch 10/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2558 - mean_squared_error: 0.2558 - val_loss: 0.2864 - val_mean_squared_error: 0.2864
# Epoch 11/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2429 - mean_squared_error: 0.2429 - val_loss: 0.2497 - val_mean_squared_error: 0.2497
# Epoch 12/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2134 - mean_squared_error: 0.2134 - val_loss: 0.2280 - val_mean_squared_error: 0.2280
# Epoch 13/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1935 - mean_squared_error: 0.1935 - val_loss: 0.1998 - val_mean_squared_error: 0.1998
# Epoch 14/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1823 - mean_squared_error: 0.1823 - val_loss: 0.2030 - val_mean_squared_error: 0.2030
# Epoch 15/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1009 - mean_squared_error: 0.1009 - val_loss: 0.1408 - val_mean_squared_error: 0.1408
# Epoch 84/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0931 - mean_squared_error: 0.0931 - val_loss: 0.1604 - val_mean_squared_error: 0.1604
# Epoch 85/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0899 - mean_squared_error: 0.0899 - val_loss: 0.1476 - val_mean_squared_error: 0.1476
# Epoch 86/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0905 - mean_squared_error: 0.0905 - val_loss: 0.1366 - val_mean_squared_error: 0.1366
# Epoch 87/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0858 - mean_squared_error: 0.0858 - val_loss: 0.1438 - val_mean_squared_error: 0.1438
# Epoch 88/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0868 - mean_squared_error: 0.0868 - val_loss: 0.1433 - val_mean_squared_error: 0.1433
# Epoch 89/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0867 - mean_squared_error: 0.0867 - val_loss: 0.1333 - val_mean_squared_error: 0.1333
# Epoch 90/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0903 - mean_squared_error: 0.0903 - val_loss: 0.1335 - val_mean_squared_error: 0.1335
# Epoch 91/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0858 - mean_squared_error: 0.0858 - val_loss: 0.1506 - val_mean_squared_error: 0.1506
# Epoch 92/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0918 - mean_squared_error: 0.0918 - val_loss: 0.1635 - val_mean_squared_error: 0.1635
# Epoch 93/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0876 - mean_squared_error: 0.0876 - val_loss: 0.1526 - val_mean_squared_error: 0.1526
# Epoch 94/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.1376 - val_mean_squared_error: 0.1376
# Epoch 95/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0838 - mean_squared_error: 0.0838 - val_loss: 0.1364 - val_mean_squared_error: 0.1364
# Epoch 96/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0847 - mean_squared_error: 0.0847 - val_loss: 0.1398 - val_mean_squared_error: 0.1398
# Epoch 97/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0909 - mean_squared_error: 0.0909 - val_loss: 0.1402 - val_mean_squared_error: 0.1402
# Epoch 98/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0868 - mean_squared_error: 0.0868 - val_loss: 0.1400 - val_mean_squared_error: 0.1400
# Epoch 99/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0788 - mean_squared_error: 0.0788 - val_loss: 0.1366 - val_mean_squared_error: 0.1366
# Epoch 100/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0875 - mean_squared_error: 0.0875 - val_loss: 0.1374 - val_mean_squared_error: 0.1374

# %%
y_test_pred = nn2.predict(X_test)
y_train_pred = nn2.predict(X_train)
print("Training MSE:", round(mean_squared_error(y_train, y_train_pred),4))
print("Validation MSE:", round(mean_squared_error(y_test, y_test_pred),4))
print("Validation RMSE:", round(mean_squared_error(y_test, y_test_pred)**0.5,4))
print("\nTraining r2:", round(r2_score(y_train, y_train_pred),4))
print("Validation r2:", round(r2_score(y_test, y_test_pred),4))
# Out:
# Training MSE: 0.0862
# Validation MSE: 0.1282
# Validation RMSE: 0.3581
#
# Training r2: 0.7899
# Validation r2: 0.6704

# %% [markdown]
# # LassoCV Model

# %%
from sklearn.linear_model import Lasso, LassoCV

# Run the cross validation, find the best alpha, refit the model on all the data with that alpha
alphavec = 10**np.linspace(-2,2,200)
lasso_model = LassoCV(alphas = alphavec, cv=5)
lasso_model.fit(X_train, y_train)
# Out:
# LassoCV(alphas=array([1.00000000e-02, 1.04737090e-02, 1.09698580e-02, 1.14895100e-02,
#        1.20337784e-02, 1.26038293e-02, 1.32008840e-02, 1.38262217e-02,
#        1.44811823e-02, 1.51671689e-02, 1.58856513e-02, 1.66381689e-02,
#        1.74263339e-02, 1.82518349e-02, 1.91164408e-02, 2.00220037e-02,
#        2.09704640e-02, 2.19638537e-02, 2.30043012e-02, 2.40940356e-02,
#        2.52353917e-02, 2.64308149e-0...
#        3.44896226e+01, 3.61234270e+01, 3.78346262e+01, 3.96268864e+01,
#        4.15040476e+01, 4.34701316e+01, 4.55293507e+01, 4.76861170e+01,
#        4.99450512e+01, 5.23109931e+01, 5.47890118e+01, 5.73844165e+01,
#        6.01027678e+01, 6.29498899e+01, 6.59318827e+01, 6.90551352e+01,
#        7.23263390e+01, 7.57525026e+01, 7.93409667e+01, 8.30994195e+01,
#        8.70359136e+01, 9.11588830e+01, 9.54771611e+01, 1.00000000e+02]),
#         cv=5)

# %%
# R2 of Training set
lasso_model.score(X_train,y_train)

# Predict model on test data
y_pred = lasso_model.predict(X_test)

#Mean Absolute Error (MAE)
def mae(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true))
print('MAE: %.3f' % mae(y_test, y_pred))

rmse_rf= (mean_squared_error(y_test,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# MAE: 0.337
# RMSE test: 0.426
# R^2 test: 0.534

# %%
plt.scatter(y_test, y_pred)
plt.plot([0,10],[0,10],color='red')
plt.grid(True)
plt.title('Predicted vs. Actual Price with LASSO CV')
plt.ylabel('Price Predicted')
plt.xlabel('Price Actual');

# %% [markdown]
# # RidgeCV Model

# %%
from sklearn.linear_model import RidgeCV

reg_params = 10.**np.linspace(-10, 5, 10)
ridge_model = RidgeCV(alphas=reg_params, fit_intercept=True, cv=5)
ridge_model.fit(X_train, y_train)
# Out:
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.55554e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.83603e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.18095e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.52823e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=5.28629e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.13986e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.17451e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.86988e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.03216e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.43247e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# RidgeCV(alphas=array([1.00000000e-10, 4.64158883e-09, 2.15443469e-07, 1.00000000e-05,
#        4.64158883e-04, 2.15443469e-02, 1.00000000e+00, 4.64158883e+01,
#        2.15443469e+03, 1.00000000e+05]),
#         cv=5)

# %%
# R2 of Training set
ridge_model.score(X_train,y_train)

# Predict model on test data
y_pred = ridge_model.predict(X_test)

#Mean Absolute Error (MAE)
def mae(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true))
print('MAE: %.3f' % mae(y_test, y_pred))

rmse_rf= (mean_squared_error(y_test,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# MAE: 0.286
# RMSE test: 0.372
# R^2 test: 0.645

# %%
plt.scatter(y_test, y_pred)
plt.plot([0,10],[0,10],color='red')
plt.grid(True)
plt.title('Predicted vs. Actual Price with RIDGE CV')
plt.ylabel('Price Predicted')
plt.xlabel('Price Actual')
# Out:
# Text(0.5, 0, 'Price Actual')

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
SVRmodel = SVR(kernel = 'linear')
SVRmodel.fit(X_train, y_train)

y_pred = SVRmodel.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# RMSE test: 0.370
# R^2 test: 0.648

# %%
from sklearn.svm import LinearSVR
LinearSVRmodel = LinearSVR()
LinearSVRmodel.fit(X_train, y_train)

y_pred = LinearSVRmodel.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# RMSE test: 1.059
# R^2 test: -1.882
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
from sklearn.svm import NuSVR
NuSVRmodel = NuSVR(kernel = 'linear')
NuSVRmodel.fit(X_train, y_train)

y_pred = NuSVRmodel.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))

# %% [markdown]
# # Distribution of Numeric Columns

# %%
new_numeric_cols = []
for col in new_SF_df.columns: 
    if col in numeric_columns:
        new_numeric_cols.append(col)
        try:      
            new_SF_df[col] = pd.to_numeric(new_SF_df[col]) 
            new_SF_df.hist(column=col)
        except ValueError:
            print('This column can not be represented as a histogram')
# Out:
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:184: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

y = new_SF_df[['price_log']] # target/dependent variable
x = new_SF_df.drop(['price','price_log'], axis =1) # independent variables

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler
X_train_sc = StandardScaler()
y_train_sc = StandardScaler()
X_test_sc = StandardScaler()
y_test_sc = StandardScaler()

X_train_scaled = X_train_sc.fit_transform(X_train)
y_train_scaled = y_train_sc.fit_transform(y_train)
X_test_scaled = X_test_sc.fit_transform(X_test)
y_test_scaled = y_test_sc.fit_transform(y_test)

# %%
from sklearn.svm import NuSVR
NuSVRmodel = NuSVR(kernel = 'linear')
NuSVRmodel.fit(X_train_scaled, y_train_scaled)

y_pred = NuSVRmodel.predict(X_test_scaled)
rmse_rf= (mean_squared_error(y_test_scaled,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test_scaled, y_pred)))
# Out:
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# RMSE test: 0.584
# R^2 test: 0.659
