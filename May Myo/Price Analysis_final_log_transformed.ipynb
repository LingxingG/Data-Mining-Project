# %% [markdown]
# # Refer to SF EDA notebook for Price EDA (Section 5 & 10)

# %% [markdown]
# # Import Libraries

# %%
# pip install -r "../requirements.txt"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %% [markdown]
# # Import Data

# %%
SF_df = pd.read_pickle("remove_features_without_encoding.pkl")
SF_df.tail(5)
# Out:
#      host_response_time  host_response_rate  host_acceptance_rate  \
# 6804                  -                 0.0                  1.00
# 6805                  -                 0.0                  1.00
# 6806     within an hour                 1.0                  1.00
# 6807     within an hour                 1.0                  0.97
# 6808     within an hour                 1.0                  1.00
#
#       host_is_superhost  host_listings_count neighbourhood_cleansed  \
# 6804                  0                    3      Visitacion Valley
# 6805                  0                    0      Visitacion Valley
# 6806                  0                    0      Visitacion Valley
# 6807                  1                    6      Visitacion Valley
# 6808                  1                    2      Visitacion Valley
#
#                   property_type        room_type  accommodates  bathrooms  \
# 6804          Entire guesthouse  Entire home/apt             2        1.0
# 6805         Entire guest suite  Entire home/apt             2        1.0
# 6806  Private room in apartment     Private room             4        1.0
# 6807           Entire apartment  Entire home/apt            10        3.0
# 6808               Entire house  Entire home/apt             4        2.0
#
#       ... game console  stair gates  fireplace guards  pocket wifi  \
# 6804  ...            0            0                 0            0
# 6805  ...            0            0                 0            0
# 6806  ...            0            0                 0            0
# 6807  ...            1            1                 1            0
# 6808  ...            0            0                 0            0
#
#       changing table  window guards  beach essentials  ev charger  beachfront  \
# 6804               0              0                 0           0           0
# 6805               0              1                 0           0           0
# 6806               0              0                 0           0           0
# 6807               0              0                 0           0           0
# 6808               0              0                 0           0           0
#
#       bread maker
# 6804            0
# 6805            0
# 6806            0
# 6807            0
# 6808            0
#
# [5 rows x 80 columns]

# %%
SF_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6809 entries, 0 to 6808
# Data columns (total 80 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   host_response_time          6809 non-null   object
#  1   host_response_rate          6809 non-null   float64
#  2   host_acceptance_rate        6809 non-null   float64
#  3   host_is_superhost           6809 non-null   int32
#  4   host_listings_count         6809 non-null   int64
#  5   neighbourhood_cleansed      6809 non-null   object
#  6   property_type               6809 non-null   object
#  7   room_type                   6809 non-null   object
#  8   accommodates                6809 non-null   int64
#  9   bathrooms                   6809 non-null   float64
#  10  amenities                   6809 non-null   object
#  11  price                       6809 non-null   float64
#  12  minimum_nights              6809 non-null   int64
#  13  review_scores_rating        6809 non-null   float64
#  14  reviews_per_month           6809 non-null   float64
#  15  price_log                   6809 non-null   float64
#  16  SafeIndex_Score             6809 non-null   float64
#  17  wifi                        6809 non-null   int64
#  18  smoke alarm                 6809 non-null   int64
#  19  heating                     6809 non-null   int64
#  20  essentials                  6809 non-null   int64
#  21  hair dryer                  6809 non-null   int64
#  22  tv                          6809 non-null   int64
#  23  kitchen                     6809 non-null   int64
#  24  washer                      6809 non-null   int64
#  25  fire extinguisher           6809 non-null   int64
#  26  hot water                   6809 non-null   int64
#  27  refrigerator                6809 non-null   int64
#  28  coffee maker                6809 non-null   int64
#  29  first aid kit               6809 non-null   int64
#  30  bed linens                  6809 non-null   int64
#  31  free street parking         6809 non-null   int64
#  32  oven                        6809 non-null   int64
#  33  private entrance            6809 non-null   int64
#  34  dishwasher                  6809 non-null   int64
#  35  cable tv                    6809 non-null   int64
#  36  long term stays allowed     6809 non-null   int64
#  37  luggage dropoff allowed     6809 non-null   int64
#  38  garden or backyard          6809 non-null   int64
#  39  lock on bedroom door        6809 non-null   int64
#  40  patio or balcony            6809 non-null   int64
#  41  lockbox                     6809 non-null   int64
#  42  elevator                    6809 non-null   int64
#  43  free parking on premises    6809 non-null   int64
#  44  bathtub                     6809 non-null   int64
#  45  keypad                      6809 non-null   int64
#  46  indoor fireplace            6809 non-null   int64
#  47  air conditioning            6809 non-null   int64
#  48  paid parking off premises   6809 non-null   int64
#  49  bbq grill                   6809 non-null   int64
#  50  breakfast                   6809 non-null   int64
#  51  pack 'n play/travel crib    6809 non-null   int64
#  52  host greets you             6809 non-null   int64
#  53  paid parking on premises    6809 non-null   int64
#  54  shower gel                  6809 non-null   int64
#  55  room-darkening shades       6809 non-null   int64
#  56  children's books and toys   6809 non-null   int64
#  57  single level home           6809 non-null   int64
#  58  private living room         6809 non-null   int64
#  59  ethernet connection         6809 non-null   int64
#  60  building staff              6809 non-null   int64
#  61  smart lock                  6809 non-null   int64
#  62  hot tub                     6809 non-null   int64
#  63  baking sheet                6809 non-null   int64
#  64  high chair                  6809 non-null   int64
#  65  cleaning before checkout    6809 non-null   int64
#  66  bathroom essentials         6809 non-null   int64
#  67  crib                        6809 non-null   int64
#  68  pool                        6809 non-null   int64
#  69  babysitter recommendations  6809 non-null   int64
#  70  game console                6809 non-null   int64
#  71  stair gates                 6809 non-null   int64
#  72  fireplace guards            6809 non-null   int64
#  73  pocket wifi                 6809 non-null   int64
#  74  changing table              6809 non-null   int64
#  75  window guards               6809 non-null   int64
#  76  beach essentials            6809 non-null   int64
#  77  ev charger                  6809 non-null   int64
#  78  beachfront                  6809 non-null   int64
#  79  bread maker                 6809 non-null   int64
# dtypes: float64(8), int32(1), int64(66), object(5)
# memory usage: 4.1+ MB

# %% [markdown]
# # Different column type name lists

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_columns = SF_df.select_dtypes(include=numerics).columns.to_list()
bool_columns = SF_df.select_dtypes(include='bool').columns.to_list()
object_columns = SF_df.select_dtypes(include='object').columns.to_list()
print(f"No. of numeric cols: {len(numeric_columns)}")
print(f"No. of boolean cols: {len(bool_columns)}")
print(f"No. of object cols: {len(object_columns)}")
print(f"Total: {len(numeric_columns)+len(bool_columns)+len(object_columns)}")
print("Object Columns :",object_columns)
# Out:
# No. of numeric cols: 75
# No. of boolean cols: 0
# No. of object cols: 5
# Total: 80
# Object Columns : ['host_response_time', 'neighbourhood_cleansed', 'property_type', 'room_type', 'amenities']

# %%
SF_df.isnull().sum()
# Out:
# host_response_time      0
# host_response_rate      0
# host_acceptance_rate    0
# host_is_superhost       0
# host_listings_count     0
#                        ..
# window guards           0
# beach essentials        0
# ev charger              0
# beachfront              0
# bread maker             0
# Length: 80, dtype: int64

# %% [markdown]
# ## Transforming categorical columns to numeric columns and combine all into new df

# %%
new_SF_df = SF_df[numeric_columns]
new_SF_df.shape
# Out:
# (6809, 75)

# %%
for categorical_col in object_columns[:-1]:
    new_SF_df = pd.concat([new_SF_df, pd.get_dummies(SF_df[categorical_col])], axis=1)

# %%
new_SF_df
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                   1.00                  0.99                  1
# 1                   0.97                  0.79                  1
# 2                   0.50                  0.76                  1
# 3                   0.50                  0.76                  1
# 4                   1.00                  1.00                  0
# ...                  ...                   ...                ...
# 6804                0.00                  1.00                  0
# 6805                0.00                  1.00                  0
# 6806                1.00                  1.00                  0
# 6807                1.00                  0.97                  1
# 6808                1.00                  1.00                  1
#
#       host_listings_count  accommodates  bathrooms  price  minimum_nights  \
# 0                       1             3        1.0  132.0               2
# 1                      38             5        2.0  166.0              30
# 2                       3             2        1.0  130.0               2
# 3                       3             2        1.0  110.0               2
# 4                       2            10        2.0  480.0               3
# ...                   ...           ...        ...    ...             ...
# 6804                    3             2        1.0  179.0               2
# 6805                    0             2        1.0  190.0              30
# 6806                    0             4        1.0   85.0               1
# 6807                    6            10        3.0  451.0               2
# 6808                    2             4        2.0  139.0               1
#
#       review_scores_rating  reviews_per_month  ...  Shared room in hostel  \
# 0                     97.0               1.91  ...                      0
# 1                     91.0               0.15  ...                      0
# 2                     97.0               3.92  ...                      0
# 3                     98.0               3.73  ...                      0
# 4                     91.0               0.32  ...                      0
# ...                    ...                ...  ...                    ...
# 6804                 100.0               0.47  ...                      0
# 6805                 100.0               0.48  ...                      0
# 6806                 100.0               0.34  ...                      0
# 6807                   0.0               0.00  ...                      0
# 6808                   0.0               0.00  ...                      0
#
#       Shared room in house  Shared room in loft  Shared room in townhouse  \
# 0                        0                    0                         0
# 1                        0                    0                         0
# 2                        0                    0                         0
# 3                        0                    0                         0
# 4                        0                    0                         0
# ...                    ...                  ...                       ...
# 6804                     0                    0                         0
# 6805                     0                    0                         0
# 6806                     0                    0                         0
# 6807                     0                    0                         0
# 6808                     0                    0                         0
#
#       Shared room in villa  Tiny house  Entire home/apt  Hotel room  \
# 0                        0           0                1           0
# 1                        0           0                1           0
# 2                        0           0                0           0
# 3                        0           0                0           0
# 4                        0           0                1           0
# ...                    ...         ...              ...         ...
# 6804                     0           0                1           0
# 6805                     0           0                1           0
# 6806                     0           0                0           0
# 6807                     0           0                1           0
# 6808                     0           0                1           0
#
#       Private room  Shared room
# 0                0            0
# 1                0            0
# 2                1            0
# 3                1            0
# 4                0            0
# ...            ...          ...
# 6804             0            0
# 6805             0            0
# 6806             1            0
# 6807             0            0
# 6808             0            0
#
# [6809 rows x 171 columns]

# %%
new_SF_df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False])

# %%
new_SF_df.columns.values[169] = "Private room (Room Type)"
new_SF_df.columns.values[169]
# Out:
# 'Private room (Room Type)'

# %%
new_SF_df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
print(new_SF_df.duplicated().any())
if new_SF_df.duplicated().any():
    duplicate_rows = new_SF_df[new_SF_df.duplicated()]
    print(duplicate_rows)
    new_SF_df = new_SF_df.drop_duplicates()
    print("Duplicates Removed")
print(new_SF_df.duplicated().any())
# Out:
# True
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 353                 1.00                  1.00                  0
# 456                 0.97                  0.95                  0
# 1109                0.90                  0.97                  0
# 1127                0.97                  0.95                  0
# 1599                1.00                  1.00                  0
# 1611                0.60                  0.79                  0
# 1622                0.60                  0.79                  0
# 1700                0.97                  0.95                  0
# 1729                1.00                  1.00                  0
# 1740                1.00                  1.00                  0
# 1943                1.00                  1.00                  0
# 1944                1.00                  1.00                  0
# 2059                0.00                  0.00                  0
# 2087                0.00                  0.50                  0
# 2088                0.00                  0.50                  0
# 2153                0.66                  1.00                  0
# 2157                0.60                  0.79                  0
# 2162                0.60                  0.79                  0
# 2163                0.60                  0.79                  0
# 2496                0.00                  0.99                  0
# 2504                0.00                  0.99                  0
# 2756                0.90                  0.97                  0
# 2807                1.00                  0.99                  0
# 2843                1.00                  1.00                  0
# 2844                1.00                  1.00                  0
# 5623                0.97                  0.95                  0
# 5766                0.25                  1.00                  0
# 6248                1.00                  0.89                  0
# 6256                0.25                  1.00                  0
# 6665                1.00                  0.96                  1
#
#       host_listings_count  accommodates  bathrooms  price  minimum_nights  \
# 353                    15             3        2.0   25.0              30
# 456                    70             1        3.0   32.0              30
# 1109                   51             1        3.0   34.0              30
# 1127                   70             1        3.0   32.0              30
# 1599                   92             2        1.0   88.0              30
# 1611                   88             2        5.0   67.0              30
# 1622                   88             2        5.0   62.0              30
# 1700                   70             1        1.0   34.0              30
# 1729                   92             2        1.0   89.0              30
# 1740                   92             2        1.0   70.0              30
# 1943                    6             2        1.0  119.0              30
# 1944                    6             2        1.0  119.0              30
# 2059                   32             2        5.0   73.0              30
# 2087                   32             2        5.0   73.0              30
# 2088                   32             2        5.0   62.0              30
# 2153                   11             2        1.0  219.0               1
# 2157                   88             1        5.0   60.0              30
# 2162                   88             2        5.0   62.0              30
# 2163                   88             2        5.0   62.0              30
# 2496                   42             2        1.0   75.0               1
# 2504                   42             2        1.0   75.0               1
# 2756                   51             1        4.0   55.0              30
# 2807                 1903             6        2.0  525.0               2
# 2843                   10             1        0.0   37.0               1
# 2844                   92             2        1.0   62.0              30
# 5623                   70             1        1.0   34.0              30
# 5766                  108             2        1.0  110.0              30
# 6248                    8             2        8.0  162.0               1
# 6256                  108             3        1.0  140.0              30
# 6665                    7             1        1.0   49.0               5
#
#       review_scores_rating  reviews_per_month  ...  Shared room in hostel  \
# 353                    0.0               0.00  ...                      0
# 456                    0.0               0.00  ...                      0
# 1109                   0.0               0.00  ...                      0
# 1127                   0.0               0.00  ...                      0
# 1599                   0.0               0.00  ...                      0
# 1611                   0.0               0.00  ...                      0
# 1622                   0.0               0.00  ...                      0
# 1700                   0.0               0.00  ...                      0
# 1729                   0.0               0.00  ...                      0
# 1740                   0.0               0.00  ...                      0
# 1943                   0.0               0.00  ...                      0
# 1944                   0.0               0.00  ...                      0
# 2059                   0.0               0.00  ...                      0
# 2087                   0.0               0.00  ...                      0
# 2088                   0.0               0.00  ...                      0
# 2153                   0.0               0.00  ...                      0
# 2157                   0.0               0.00  ...                      0
# 2162                 100.0               0.08  ...                      0
# 2163                   0.0               0.00  ...                      0
# 2496                  80.0               0.07  ...                      0
# 2504                 100.0               0.04  ...                      0
# 2756                   0.0               0.00  ...                      0
# 2807                   0.0               0.00  ...                      0
# 2843                   0.0               0.00  ...                      1
# 2844                   0.0               0.00  ...                      0
# 5623                   0.0               0.00  ...                      0
# 5766                   0.0               0.00  ...                      0
# 6248                   0.0               0.00  ...                      0
# 6256                   0.0               0.00  ...                      0
# 6665                   0.0               0.00  ...                      0
#
#       Shared room in house  Shared room in loft  Shared room in townhouse  \
# 353                      0                    0                         0
# 456                      0                    0                         0
# 1109                     0                    0                         0
# 1127                     0                    0                         0
# 1599                     0                    0                         0
# 1611                     0                    0                         0
# 1622                     0                    0                         0
# 1700                     0                    0                         0
# 1729                     0                    0                         0
# 1740                     0                    0                         0
# 1943                     0                    0                         0
# 1944                     0                    0                         0
# 2059                     0                    0                         0
# 2087                     0                    0                         0
# 2088                     0                    0                         0
# 2153                     0                    0                         0
# 2157                     0                    0                         0
# 2162                     0                    0                         0
# 2163                     0                    0                         0
# 2496                     0                    0                         0
# 2504                     0                    0                         0
# 2756                     0                    0                         0
# 2807                     0                    0                         0
# 2843                     0                    0                         0
# 2844                     0                    0                         0
# 5623                     0                    0                         0
# 5766                     0                    0                         0
# 6248                     0                    0                         0
# 6256                     0                    0                         0
# 6665                     0                    0                         0
#
#       Shared room in villa  Tiny house  Entire home/apt  Hotel room  \
# 353                      0           0                0           0
# 456                      0           0                0           0
# 1109                     0           0                0           0
# 1127                     0           0                0           0
# 1599                     0           0                1           0
# 1611                     0           0                0           0
# 1622                     0           0                0           0
# 1700                     0           0                0           0
# 1729                     0           0                1           0
# 1740                     0           0                1           0
# 1943                     0           0                1           0
# 1944                     0           0                1           0
# 2059                     0           0                0           0
# 2087                     0           0                0           0
# 2088                     0           0                0           0
# 2153                     0           0                0           0
# 2157                     0           0                0           0
# 2162                     0           0                0           0
# 2163                     0           0                0           0
# 2496                     0           0                0           0
# 2504                     0           0                0           0
# 2756                     0           0                0           0
# 2807                     0           0                1           0
# 2843                     0           0                0           0
# 2844                     0           0                1           0
# 5623                     0           0                0           0
# 5766                     0           0                1           0
# 6248                     0           0                0           0
# 6256                     0           0                1           0
# 6665                     0           0                0           0
#
#       Private room (Room Type)  Shared room
# 353                          0            1
# 456                          0            1
# 1109                         0            1
# 1127                         0            1
# 1599                         0            0
# 1611                         1            0
# 1622                         1            0
# 1700                         0            1
# 1729                         0            0
# 1740                         0            0
# 1943                         0            0
# 1944                         0            0
# 2059                         1            0
# 2087                         1            0
# 2088                         1            0
# 2153                         1            0
# 2157                         1            0
# 2162                         1            0
# 2163                         1            0
# 2496                         1            0
# 2504                         1            0
# 2756                         1            0
# 2807                         0            0
# 2843                         0            1
# 2844                         0            0
# 5623                         0            1
# 5766                         0            0
# 6248                         1            0
# 6256                         0            0
# 6665                         1            0
#
# [30 rows x 171 columns]
# Duplicates Removed
# False

# %%
new_SF_df
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0                   1.00                  0.99                  1
# 1                   0.97                  0.79                  1
# 2                   0.50                  0.76                  1
# 3                   0.50                  0.76                  1
# 4                   1.00                  1.00                  0
# ...                  ...                   ...                ...
# 6804                0.00                  1.00                  0
# 6805                0.00                  1.00                  0
# 6806                1.00                  1.00                  0
# 6807                1.00                  0.97                  1
# 6808                1.00                  1.00                  1
#
#       host_listings_count  accommodates  bathrooms  price  minimum_nights  \
# 0                       1             3        1.0  132.0               2
# 1                      38             5        2.0  166.0              30
# 2                       3             2        1.0  130.0               2
# 3                       3             2        1.0  110.0               2
# 4                       2            10        2.0  480.0               3
# ...                   ...           ...        ...    ...             ...
# 6804                    3             2        1.0  179.0               2
# 6805                    0             2        1.0  190.0              30
# 6806                    0             4        1.0   85.0               1
# 6807                    6            10        3.0  451.0               2
# 6808                    2             4        2.0  139.0               1
#
#       review_scores_rating  reviews_per_month  ...  Shared room in hostel  \
# 0                     97.0               1.91  ...                      0
# 1                     91.0               0.15  ...                      0
# 2                     97.0               3.92  ...                      0
# 3                     98.0               3.73  ...                      0
# 4                     91.0               0.32  ...                      0
# ...                    ...                ...  ...                    ...
# 6804                 100.0               0.47  ...                      0
# 6805                 100.0               0.48  ...                      0
# 6806                 100.0               0.34  ...                      0
# 6807                   0.0               0.00  ...                      0
# 6808                   0.0               0.00  ...                      0
#
#       Shared room in house  Shared room in loft  Shared room in townhouse  \
# 0                        0                    0                         0
# 1                        0                    0                         0
# 2                        0                    0                         0
# 3                        0                    0                         0
# 4                        0                    0                         0
# ...                    ...                  ...                       ...
# 6804                     0                    0                         0
# 6805                     0                    0                         0
# 6806                     0                    0                         0
# 6807                     0                    0                         0
# 6808                     0                    0                         0
#
#       Shared room in villa  Tiny house  Entire home/apt  Hotel room  \
# 0                        0           0                1           0
# 1                        0           0                1           0
# 2                        0           0                0           0
# 3                        0           0                0           0
# 4                        0           0                1           0
# ...                    ...         ...              ...         ...
# 6804                     0           0                1           0
# 6805                     0           0                1           0
# 6806                     0           0                0           0
# 6807                     0           0                1           0
# 6808                     0           0                1           0
#
#       Private room (Room Type)  Shared room
# 0                            0            0
# 1                            0            0
# 2                            1            0
# 3                            1            0
# 4                            0            0
# ...                        ...          ...
# 6804                         0            0
# 6805                         0            0
# 6806                         1            0
# 6807                         0            0
# 6808                         0            0
#
# [6779 rows x 171 columns]

# %% [markdown]
# # Train/Test split

# %%
from sklearn.model_selection import train_test_split
y = new_SF_df['price_log'] # target/dependent variable
x = new_SF_df.drop(['price','price_log'], axis =1) # independent variables

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state=1)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Train/Test w Random Forest Algorithm

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=500, 
                               criterion='mse', 
                               random_state=3, 
                               n_jobs=-1)
rf.fit(X_train, y_train)
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 0.350
# R^2 test: 0.695

# %% [markdown]
# ## Feature Importance of Random Forest Algorithm

# %%
coefs_df = pd.DataFrame()
coefs_df['feature'] = X_train.columns
coefs_df['coefs'] = rf.feature_importances_
coefs_df.sort_values('coefs', ascending=False).head(20)
# Out:
#                       feature     coefs
# 4                accommodates  0.289337
# 6              minimum_nights  0.103381
# 165           Entire home/apt  0.081279
# 8           reviews_per_month  0.055135
# 168               Shared room  0.051128
# 5                   bathrooms  0.037687
# 3         host_listings_count  0.030989
# 9             SafeIndex_Score  0.026436
# 1        host_acceptance_rate  0.024181
# 7        review_scores_rating  0.019220
# 40           air conditioning  0.017354
# 27                 dishwasher  0.014079
# 0          host_response_rate  0.014018
# 167  Private room (Room Type)  0.009457
# 2           host_is_superhost  0.007745
# 18          fire extinguisher  0.006244
# 73                          -  0.005932
# 141     Private room in house  0.004982
# 15                         tv  0.004815
# 28                   cable tv  0.004736

# %%
feat_imp = pd.Series(rf.feature_importances_, index=X_train.columns)
feat_imp.nlargest(20).plot(kind='barh', figsize=(10,6))

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## Train/Test w LightGBM

# %%
from lightgbm import LGBMRegressor

fit_params={
    "early_stopping_rounds":20, 
            "eval_metric" : 'rmse', 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            'verbose': 100,
            'feature_name': 'auto', 
            'categorical_feature': 'auto'
           }
        
class LGBMRegressor_GainFE(LGBMRegressor):
    @property
    def feature_importances_(self):
        if self._n_features is None:
            raise LGBMNotFittedError('No feature_importances found. Need to call fit beforehand.')
        return self.booster_.feature_importance(importance_type='gain')
        
clf = LGBMRegressor_GainFE(num_leaves= 25, max_depth=20, 
                         random_state=0, 
                         silent=True, 
                         metric='rmse', 
                         n_jobs=4, 
                         n_estimators=1000,
                         colsample_bytree=0.9,
                         subsample=0.9,
                         learning_rate=0.01)
clf.fit(X_train.values, y_train.values, **fit_params)
y_pred = clf.predict(X_test.values)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# Training until validation scores don't improve for 20 rounds
# [100]	valid's rmse: 0.439118
# [200]	valid's rmse: 0.383945
# [300]	valid's rmse: 0.362342
# [400]	valid's rmse: 0.351344
# [500]	valid's rmse: 0.345935
# [600]	valid's rmse: 0.343266
# [700]	valid's rmse: 0.341583
# [800]	valid's rmse: 0.340574
# [900]	valid's rmse: 0.339898
# [1000]	valid's rmse: 0.338985
# Did not meet early stopping. Best iteration is:
# [998]	valid's rmse: 0.338969
# R^2 test: 0.713

# %% [markdown]
# ## Feature Importance of LightGBM

# %%
feat_imp = pd.Series(clf.feature_importances_, index=x.columns)
feat_imp.nlargest(20).plot(kind='barh', figsize=(10,6))

# %%
coefs_df = pd.DataFrame()
coefs_df['feature'] = x.columns
coefs_df['coefs'] = clf.feature_importances_
coefs_df.sort_values('coefs', ascending=False).head(20)
# Out:
#                       feature         coefs
# 4                accommodates  30227.394923
# 6              minimum_nights   8603.220109
# 165           Entire home/apt   8344.226645
# 168               Shared room   4311.650667
# 5                   bathrooms   4241.624347
# 8           reviews_per_month   4010.240069
# 3         host_listings_count   2961.406357
# 1        host_acceptance_rate   1999.311215
# 9             SafeIndex_Score   1889.447186
# 40           air conditioning   1600.565149
# 167  Private room (Room Type)   1592.525629
# 0          host_response_rate   1373.476393
# 7        review_scores_rating   1257.740636
# 27                 dishwasher   1107.875817
# 15                         tv    777.730844
# 141     Private room in house    645.328609
# 35                   elevator    640.346396
# 2           host_is_superhost    486.727662
# 18          fire extinguisher    433.161857
# 78                    Bayview    406.857941

# %% [markdown]
# # Gradient Boosting

# %% [markdown]
# ## Train/Test w Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor


gboost = GradientBoostingRegressor(n_estimators=500, 
                               criterion='mse', 
                               random_state=3)
gboost.fit(X_train, y_train)
y_train_pred = gboost.predict(X_train)
y_test_pred = gboost.predict(X_test)
rmse_rf= (mean_squared_error(y_test,y_test_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_test_pred)))
# Out:
# RMSE test: 0.342
# R^2 test: 0.708

# %% [markdown]
# ## Feature Importance of Gradient Boosting

# %%
coefs_df = pd.DataFrame()
coefs_df['feature'] = X_train.columns
coefs_df['coefs'] = gboost.feature_importances_
coefs_df.sort_values('coefs', ascending=False).head(20)
# Out:
#                       feature     coefs
# 4                accommodates  0.311255
# 6              minimum_nights  0.106181
# 165           Entire home/apt  0.103436
# 168               Shared room  0.070833
# 5                   bathrooms  0.045140
# 8           reviews_per_month  0.038883
# 3         host_listings_count  0.032762
# 0          host_response_rate  0.022140
# 1        host_acceptance_rate  0.020318
# 167  Private room (Room Type)  0.019437
# 9             SafeIndex_Score  0.018096
# 7        review_scores_rating  0.014341
# 40           air conditioning  0.013679
# 27                 dishwasher  0.012393
# 35                   elevator  0.011487
# 15                         tv  0.009616
# 14                 hair dryer  0.005692
# 37                    bathtub  0.005505
# 10                       wifi  0.005287
# 78                    Bayview  0.004667

# %%
feat_imp = pd.Series(gboost.feature_importances_, index=X_train.columns)
feat_imp.nlargest(20).plot(kind='barh', figsize=(10,6))

# %% [markdown]
# # XGBoost and its Feature Importance

# %%
import xgboost as xgb

# Fitting the model
xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train, y_train)
training_preds_xgb_reg = xgb_reg.predict(X_train)
val_preds_xgb_reg = xgb_reg.predict(X_test)

# Printing the results

print("\nTraining MSE:", round(mean_squared_error(y_train, training_preds_xgb_reg),4))
print("Validation MSE:", round(mean_squared_error(y_test, val_preds_xgb_reg),4))
print("Validation RMSE:", round(mean_squared_error(y_test, val_preds_xgb_reg)**0.5,4))
print("\nTraining r2:", round(r2_score(y_train, training_preds_xgb_reg),4))
print("Validation r2:", round(r2_score(y_test, val_preds_xgb_reg),4))

# Producing a dataframe of feature importances
ft_weights_xgb_reg = pd.DataFrame(xgb_reg.feature_importances_, columns=['weight'], index=X_train.columns)
ft_weights_xgb_reg.sort_values('weight', inplace=True)

# Plotting feature importances
plt.figure(figsize=(8,20))
plt.barh(ft_weights_xgb_reg.index, ft_weights_xgb_reg.weight, align='center') 
plt.title("Feature importances in the XGBoost model", fontsize=14)
plt.xlabel("Feature importance")
plt.margins(y=0.01)
plt.show()
# Out:
# Training MSE: 0.0256
# Validation MSE: 0.1191
# Validation RMSE: 0.3451
#
# Training r2: 0.9374
# Validation r2: 0.703

# %% [markdown]
# # Neural Network Model

# %%
from keras import models, layers, optimizers, regularizers
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG

# Building the model
nn2 = models.Sequential()
nn2.add(layers.Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(256, activation='relu'))
nn2.add(layers.Dense(512, activation='relu'))
nn2.add(layers.Dense(1, activation='linear'))

# Compiling the model
nn2.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['mean_squared_error'])

# Printing the model summary
print(nn2.summary())

# Training the model
nn2_history = nn2.fit(X_train,
                  y_train,
                  epochs=100,
                  batch_size=256,
                  validation_split = 0.1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               21760
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 252,673
# Trainable params: 252,673
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 18/18 [==============================] - 0s 23ms/step - loss: 47.0516 - mean_squared_error: 47.0516 - val_loss: 5.5326 - val_mean_squared_error: 5.5326
# Epoch 2/100
# 18/18 [==============================] - 0s 10ms/step - loss: 1.8071 - mean_squared_error: 1.8071 - val_loss: 1.3463 - val_mean_squared_error: 1.3463
# Epoch 3/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6845 - mean_squared_error: 0.6845 - val_loss: 0.7339 - val_mean_squared_error: 0.7339
# Epoch 4/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4921 - mean_squared_error: 0.4921 - val_loss: 0.6334 - val_mean_squared_error: 0.6334
# Epoch 5/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.3575 - mean_squared_error: 0.3575 - val_loss: 0.4851 - val_mean_squared_error: 0.4851
# Epoch 6/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3162 - mean_squared_error: 0.3162 - val_loss: 0.3777 - val_mean_squared_error: 0.3777
# Epoch 7/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2879 - mean_squared_error: 0.2879 - val_loss: 0.4707 - val_mean_squared_error: 0.4707
# Epoch 8/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2648 - mean_squared_error: 0.2648 - val_loss: 0.2666 - val_mean_squared_error: 0.2666
# Epoch 9/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - val_loss: 0.3447 - val_mean_squared_error: 0.3447
# Epoch 10/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2209 - mean_squared_error: 0.2209 - val_loss: 0.3062 - val_mean_squared_error: 0.3062
# Epoch 11/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2230 - mean_squared_error: 0.2230 - val_loss: 0.2552 - val_mean_squared_error: 0.2552
# Epoch 12/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.2048 - mean_squared_error: 0.2048 - val_loss: 0.2779 - val_mean_squared_error: 0.2779
# Epoch 13/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1800 - mean_squared_error: 0.1800 - val_loss: 0.2329 - val_mean_squared_error: 0.2329
# Epoch 14/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2106 - mean_squared_error: 0.2106 - val_loss: 0.2705 - val_mean_squared_error: 0.2705
# Epoch 15/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1874 - mean_squared_error: 0.1874 - val_loss: 0.2698 - val_mean_squared_error: 0.2698
# Epoch 16/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.3046 - mean_squared_error: 0.3046 - val_loss: 0.2541 - val_mean_squared_error: 0.2541
# Epoch 17/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2687 - mean_squared_error: 0.2687 - val_loss: 0.5746 - val_mean_squared_error: 0.5746
# Epoch 18/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2384 - mean_squared_error: 0.2384 - val_loss: 0.2391 - val_mean_squared_error: 0.2391
# Epoch 19/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1978 - mean_squared_error: 0.1978 - val_loss: 0.2613 - val_mean_squared_error: 0.2613
# Epoch 20/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1766 - mean_squared_error: 0.1766 - val_loss: 0.2338 - val_mean_squared_error: 0.2338
# Epoch 21/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1563 - mean_squared_error: 0.1563 - val_loss: 0.2740 - val_mean_squared_error: 0.2740
# Epoch 22/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1538 - mean_squared_error: 0.1538 - val_loss: 0.1948 - val_mean_squared_error: 0.1948
# Epoch 23/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1522 - mean_squared_error: 0.1522 - val_loss: 0.2579 - val_mean_squared_error: 0.2579
# Epoch 24/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1474 - mean_squared_error: 0.1474 - val_loss: 0.1655 - val_mean_squared_error: 0.1655
# Epoch 25/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1630 - mean_squared_error: 0.1630 - val_loss: 0.1999 - val_mean_squared_error: 0.1999
# Epoch 26/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1540 - mean_squared_error: 0.1540 - val_loss: 0.3075 - val_mean_squared_error: 0.3075
# Epoch 27/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1851 - mean_squared_error: 0.1851 - val_loss: 0.1785 - val_mean_squared_error: 0.1785
# Epoch 28/100
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1672 - mean_squared_error: 0.1672 - val_loss: 0.2478 - val_mean_squared_error: 0.2478
# Epoch 29/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1710 - mean_squared_error: 0.1710 - val_loss: 0.1920 - val_mean_squared_error: 0.1920
# Epoch 30/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1668 - mean_squared_error: 0.1668 - val_loss: 0.2790 - val_mean_squared_error: 0.2790
# Epoch 31/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.2021 - mean_squared_error: 0.2021 - val_loss: 0.1817 - val_mean_squared_error: 0.1817
# Epoch 32/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1417 - mean_squared_error: 0.1417 - val_loss: 0.1676 - val_mean_squared_error: 0.1676
# Epoch 33/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.1336 - mean_squared_error: 0.1336 - val_loss: 0.2301 - val_mean_squared_error: 0.2301
# Epoch 34/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1229 - mean_squared_error: 0.1229 - val_loss: 0.1504 - val_mean_squared_error: 0.1504
# Epoch 35/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1197 - mean_squared_error: 0.1197 - val_loss: 0.1588 - val_mean_squared_error: 0.1588
# Epoch 36/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.1140 - mean_squared_error: 0.1140 - val_loss: 0.1496 - val_mean_squared_error: 0.1496
# Epoch 37/100
# 18/18 [==============================] - 0s 17ms/step - loss: 0.1217 - mean_squared_error: 0.1217 - val_loss: 0.1555 - val_mean_squared_error: 0.1555
# Epoch 38/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1121 - mean_squared_error: 0.1121 - val_loss: 0.1632 - val_mean_squared_error: 0.1632
# Epoch 39/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1108 - mean_squared_error: 0.1108 - val_loss: 0.1618 - val_mean_squared_error: 0.1618
# Epoch 40/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1179 - mean_squared_error: 0.1179 - val_loss: 0.1742 - val_mean_squared_error: 0.1742
# Epoch 41/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1164 - mean_squared_error: 0.1164 - val_loss: 0.1801 - val_mean_squared_error: 0.1801
# Epoch 42/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1114 - mean_squared_error: 0.1114 - val_loss: 0.1941 - val_mean_squared_error: 0.1941
# Epoch 43/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.1075 - mean_squared_error: 0.1075 - val_loss: 0.1774 - val_mean_squared_error: 0.1774
# Epoch 44/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.1183 - mean_squared_error: 0.1183 - val_loss: 0.1862 - val_mean_squared_error: 0.1862
# Epoch 45/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.1119 - mean_squared_error: 0.1119 - val_loss: 0.1645 - val_mean_squared_error: 0.1645
# Epoch 46/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1052 - mean_squared_error: 0.1052 - val_loss: 0.1594 - val_mean_squared_error: 0.1594
# Epoch 47/100
# 18/18 [==============================] - 0s 17ms/step - loss: 0.1925 - mean_squared_error: 0.1925 - val_loss: 0.7520 - val_mean_squared_error: 0.7520
# Epoch 48/100
# 18/18 [==============================] - ETA: 0s - loss: 0.3778 - mean_squared_error: 0.37 - 0s 20ms/step - loss: 0.3507 - mean_squared_error: 0.3507 - val_loss: 0.2135 - val_mean_squared_error: 0.2135
# Epoch 49/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.1460 - mean_squared_error: 0.1460 - val_loss: 0.2105 - val_mean_squared_error: 0.2105
# Epoch 50/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1777 - mean_squared_error: 0.1777 - val_loss: 0.1915 - val_mean_squared_error: 0.1915
# Epoch 51/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1404 - mean_squared_error: 0.1404 - val_loss: 0.2185 - val_mean_squared_error: 0.2185
# Epoch 52/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1331 - mean_squared_error: 0.1331 - val_loss: 0.1652 - val_mean_squared_error: 0.1652
# Epoch 53/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1108 - mean_squared_error: 0.1108 - val_loss: 0.1617 - val_mean_squared_error: 0.1617
# Epoch 54/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1149 - mean_squared_error: 0.1149 - val_loss: 0.1658 - val_mean_squared_error: 0.1658
# Epoch 55/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1174 - mean_squared_error: 0.1174 - val_loss: 0.2212 - val_mean_squared_error: 0.2212
# Epoch 56/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.1195 - mean_squared_error: 0.1195 - val_loss: 0.1775 - val_mean_squared_error: 0.1775
# Epoch 57/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1055 - mean_squared_error: 0.1055 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 58/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1054 - mean_squared_error: 0.1054 - val_loss: 0.2005 - val_mean_squared_error: 0.2005
# Epoch 59/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1017 - mean_squared_error: 0.1017 - val_loss: 0.1988 - val_mean_squared_error: 0.1988
# Epoch 60/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1060 - mean_squared_error: 0.1060 - val_loss: 0.1537 - val_mean_squared_error: 0.1537
# Epoch 61/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1058 - mean_squared_error: 0.1058 - val_loss: 0.1622 - val_mean_squared_error: 0.1622
# Epoch 62/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1082 - mean_squared_error: 0.1082 - val_loss: 0.1546 - val_mean_squared_error: 0.1546
# Epoch 63/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1124 - mean_squared_error: 0.1124 - val_loss: 0.1696 - val_mean_squared_error: 0.1696
# Epoch 64/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0972 - mean_squared_error: 0.0972 - val_loss: 0.1965 - val_mean_squared_error: 0.1965
# Epoch 65/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0970 - mean_squared_error: 0.0970 - val_loss: 0.1563 - val_mean_squared_error: 0.1563
# Epoch 66/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0999 - mean_squared_error: 0.0999 - val_loss: 0.1855 - val_mean_squared_error: 0.1855
# Epoch 67/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0965 - mean_squared_error: 0.0965 - val_loss: 0.1449 - val_mean_squared_error: 0.1449
# Epoch 68/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0916 - mean_squared_error: 0.0916 - val_loss: 0.1540 - val_mean_squared_error: 0.1540
# Epoch 69/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1022 - mean_squared_error: 0.1022 - val_loss: 0.1642 - val_mean_squared_error: 0.1642
# Epoch 70/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1318 - mean_squared_error: 0.1318 - val_loss: 0.1691 - val_mean_squared_error: 0.1691
# Epoch 71/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1063 - mean_squared_error: 0.1063 - val_loss: 0.1581 - val_mean_squared_error: 0.1581
# Epoch 72/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0969 - mean_squared_error: 0.0969 - val_loss: 0.2250 - val_mean_squared_error: 0.2250
# Epoch 73/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0900 - mean_squared_error: 0.0900 - val_loss: 0.1589 - val_mean_squared_error: 0.1589
# Epoch 74/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1614 - mean_squared_error: 0.1614 - val_loss: 0.2144 - val_mean_squared_error: 0.2144
# Epoch 75/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.1788 - mean_squared_error: 0.1788 - val_loss: 0.2213 - val_mean_squared_error: 0.2213
# Epoch 76/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0967 - mean_squared_error: 0.0967 - val_loss: 0.1856 - val_mean_squared_error: 0.1856
# Epoch 77/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0853 - mean_squared_error: 0.0853 - val_loss: 0.1735 - val_mean_squared_error: 0.1735
# Epoch 78/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0967 - mean_squared_error: 0.0967 - val_loss: 0.1759 - val_mean_squared_error: 0.1759
# Epoch 79/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.1185 - mean_squared_error: 0.1185 - val_loss: 0.3207 - val_mean_squared_error: 0.3207
# Epoch 80/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1268 - mean_squared_error: 0.1268 - val_loss: 0.1633 - val_mean_squared_error: 0.1633
# Epoch 81/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0949 - mean_squared_error: 0.0949 - val_loss: 0.1706 - val_mean_squared_error: 0.1706
# Epoch 82/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0906 - mean_squared_error: 0.0906 - val_loss: 0.2104 - val_mean_squared_error: 0.2104
# Epoch 83/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0887 - mean_squared_error: 0.0887 - val_loss: 0.1925 - val_mean_squared_error: 0.1925
# Epoch 84/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0832 - mean_squared_error: 0.0832 - val_loss: 0.1855 - val_mean_squared_error: 0.1855
# Epoch 85/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0825 - mean_squared_error: 0.0825 - val_loss: 0.1953 - val_mean_squared_error: 0.1953
# Epoch 86/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0804 - mean_squared_error: 0.0804 - val_loss: 0.1737 - val_mean_squared_error: 0.1737
# Epoch 87/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1085 - mean_squared_error: 0.1085 - val_loss: 0.2728 - val_mean_squared_error: 0.2728
# Epoch 88/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0931 - mean_squared_error: 0.0931 - val_loss: 0.2102 - val_mean_squared_error: 0.2102
# Epoch 89/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0839 - mean_squared_error: 0.0839 - val_loss: 0.1676 - val_mean_squared_error: 0.1676
# Epoch 90/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0763 - mean_squared_error: 0.0763 - val_loss: 0.1918 - val_mean_squared_error: 0.1918
# Epoch 91/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1041 - mean_squared_error: 0.1041 - val_loss: 0.1905 - val_mean_squared_error: 0.1905
# Epoch 92/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0904 - mean_squared_error: 0.0904 - val_loss: 0.1770 - val_mean_squared_error: 0.1770
# Epoch 93/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0870 - mean_squared_error: 0.0870 - val_loss: 0.1770 - val_mean_squared_error: 0.1770
# Epoch 94/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0805 - mean_squared_error: 0.0805 - val_loss: 0.1728 - val_mean_squared_error: 0.1728
# Epoch 95/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0778 - mean_squared_error: 0.0778 - val_loss: 0.2139 - val_mean_squared_error: 0.2139
# Epoch 96/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0813 - mean_squared_error: 0.0813 - val_loss: 0.2141 - val_mean_squared_error: 0.2141
# Epoch 97/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0793 - mean_squared_error: 0.0793 - val_loss: 0.1864 - val_mean_squared_error: 0.1864
# Epoch 98/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0886 - mean_squared_error: 0.0886 - val_loss: 0.2060 - val_mean_squared_error: 0.2060
# Epoch 99/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0890 - mean_squared_error: 0.0890 - val_loss: 0.1708 - val_mean_squared_error: 0.1708
# Epoch 100/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0727 - mean_squared_error: 0.0727 - val_loss: 0.1853 - val_mean_squared_error: 0.1853

# %%
y_test_pred = nn2.predict(X_test)
y_train_pred = nn2.predict(X_train)
print("Training MSE:", round(mean_squared_error(y_train, y_train_pred),4))
print("Validation MSE:", round(mean_squared_error(y_test, y_test_pred),4))
print("Validation RMSE:", round(mean_squared_error(y_test, y_test_pred)**0.5,4))
print("\nTraining r2:", round(r2_score(y_train, y_train_pred),4))
print("Validation r2:", round(r2_score(y_test, y_test_pred),4))
# Out:
# Training MSE: 0.0899
# Validation MSE: 0.1791
# Validation RMSE: 0.4232
#
# Training r2: 0.7799
# Validation r2: 0.5533

# %% [markdown]
# # Distribution of Numeric Columns

# %%
new_numeric_cols = []
for col in new_SF_df.columns: 
    if col in numeric_columns:
        new_numeric_cols.append(col)
        try:      
            new_SF_df[col] = pd.to_numeric(new_SF_df[col]) 
            new_SF_df.hist(column=col)
        except ValueError:
            print('This column can not be represented as a histogram')
# Out:
# <ipython-input-28-e0fb9fbfefe6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_SF_df[col] = pd.to_numeric(new_SF_df[col])
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:184: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %% [markdown]
# # LassoCV Model

# %%
from sklearn.linear_model import Lasso, LassoCV

# Run the cross validation, find the best alpha, refit the model on all the data with that alpha
alphavec = 10**np.linspace(-2,2,200)
lasso_model = LassoCV(alphas = alphavec, cv=5)
lasso_model.fit(X_train, y_train)
# Out:
# LassoCV(alphas=array([1.00000000e-02, 1.04737090e-02, 1.09698580e-02, 1.14895100e-02,
#        1.20337784e-02, 1.26038293e-02, 1.32008840e-02, 1.38262217e-02,
#        1.44811823e-02, 1.51671689e-02, 1.58856513e-02, 1.66381689e-02,
#        1.74263339e-02, 1.82518349e-02, 1.91164408e-02, 2.00220037e-02,
#        2.09704640e-02, 2.19638537e-02, 2.30043012e-02, 2.40940356e-02,
#        2.52353917e-02, 2.64308149e-0...
#        3.44896226e+01, 3.61234270e+01, 3.78346262e+01, 3.96268864e+01,
#        4.15040476e+01, 4.34701316e+01, 4.55293507e+01, 4.76861170e+01,
#        4.99450512e+01, 5.23109931e+01, 5.47890118e+01, 5.73844165e+01,
#        6.01027678e+01, 6.29498899e+01, 6.59318827e+01, 6.90551352e+01,
#        7.23263390e+01, 7.57525026e+01, 7.93409667e+01, 8.30994195e+01,
#        8.70359136e+01, 9.11588830e+01, 9.54771611e+01, 1.00000000e+02]),
#         cv=5)

# %%
# R2 of Training set
lasso_model.score(X_train,y_train)

# Predict model on test data
y_pred = lasso_model.predict(X_test)

#Mean Absolute Error (MAE)
def mae(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true))
print('MAE: %.3f' % mae(y_test, y_pred))

rmse_rf= (mean_squared_error(y_test,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# MAE: 0.348
# RMSE test: 0.452
# R^2 test: 0.490

# %%
plt.scatter(y_test, y_pred)
plt.plot([0,10],[0,10],color='red')
plt.grid(True)
plt.title('Predicted vs. Actual Price with LASSO CV')
plt.ylabel('Price Predicted')
plt.xlabel('Price Actual');

# %% [markdown]
# # RidgeCV Model

# %%
from sklearn.linear_model import RidgeCV

reg_params = 10.**np.linspace(-10, 5, 10)
ridge_model = RidgeCV(alphas=reg_params, fit_intercept=True, cv=5)
ridge_model.fit(X_train, y_train)
# Out:
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.25085e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.77992e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.34899e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.03739e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.57523e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=8.2152e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.04873e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.08001e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=4.8028e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\Anaconda3\envs\py38\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.98139e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# RidgeCV(alphas=array([1.00000000e-10, 4.64158883e-09, 2.15443469e-07, 1.00000000e-05,
#        4.64158883e-04, 2.15443469e-02, 1.00000000e+00, 4.64158883e+01,
#        2.15443469e+03, 1.00000000e+05]),
#         cv=5)

# %%
# R2 of Training set
ridge_model.score(X_train,y_train)

# Predict model on test data
y_pred = ridge_model.predict(X_test)

#Mean Absolute Error (MAE)
def mae(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true))
print('MAE: %.3f' % mae(y_test, y_pred))

rmse_rf= (mean_squared_error(y_test,y_pred))**(1/2)

print('RMSE test: %.3f' % rmse_rf)
print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
# Out:
# MAE: 0.300
# RMSE test: 0.401
# R^2 test: 0.600

# %%
plt.scatter(y_test, y_pred)
plt.plot([0,10],[0,10],color='red')
plt.grid(True)
plt.title('Predicted vs. Actual Price with RIDGE CV')
plt.ylabel('Price Predicted')
plt.xlabel('Price Actual')
# Out:
# Text(0.5, 0, 'Price Actual')
